# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishi1878/ai-resume-analyzer/blob/main/project-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
import PyPDF2

all_text = ""
with open('/content/Surisetty_Rishitha_Resume_11-05-2026.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)

    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]
        page_text = page.extract_text()
        all_text += f"\n--- Page {page_num + 1} ---\n"
        all_text += page_text

# Save the extracted text to a file
with open('extracted_text.txt', 'w', encoding='utf-8') as output_file:
    output_file.write(all_text)

print("Text extracted and saved to 'extracted_text.txt'.")
# Out:
# ...
# Text extracted and saved to 'extracted_text.txt'.

# %%
# !ls
# Out:
# sample_data
